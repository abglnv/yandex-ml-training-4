# %% [markdown]
# ## HW 4: Policy gradient
# _Reference: based on Practical RL course by YSDA_
#
# In this notebook you have to master Policy gradient Q-learning and apply it to familiar (and not so familiar) RL problems once again.
#
# To get used to `gymnasium` package, please, refer to the [documentation](https://gymnasium.farama.org/introduction/basic_usage/).
#
#
# In the end of the notebook, please, copy the functions you have implemented to the template file and submit it to the Contest.

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")

env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape

plt.imshow(env.render())
# Out:
# /Users/baga/github/ml-course/venv/lib/python3.13/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# # Building the network for Policy Gradient (REINFORCE)

# %% [markdown]
# For REINFORCE algorithm, we'll need a model that predicts action probabilities given states.
#
# For numerical stability, please __do not include the softmax layer into your network architecture__.
# We'll use softmax or log-softmax where appropriate.

# %%
import torch
import torch.nn as nn

# %%
# Build a simple neural network that predicts policy logits.
# Keep it simple: CartPole isn't worth deep architectures.
model = nn.Sequential(
    nn.Linear(in_features=4, out_features=32),
    nn.ReLU(),
    nn.Linear(in_features=32, out_features=2)
)
assert model is not None, "model is not defined"

# %% [markdown]
# #### Predicting the action probas

# %% [markdown]
# Note: **output value of this function is not a torch tensor, it's a numpy array.**
#
# So, here gradient calculation is not needed.
#
# Use [no_grad](https://pytorch.org/docs/stable/autograd.html#torch.autograd.no_grad)
# to suppress gradient calculation.
#
# Also, `.detach()` can be used instead, but there is a difference:
#
# * With `.detach()` computational graph is built but then disconnected from a particular tensor, so `.detach()` should be used if that graph is needed for backprop via some other (not detached) tensor;
# * In contrast, no graph is built by any operation in `no_grad()` context, thus it's preferable here.

# %%
def predict_probs(states):
    """
    Predict action probabilities given states.
    :param states: numpy array of shape [batch, state_shape]
    :returns: numpy array of shape [batch, n_actions]
    """
    # convert states, compute logits, use softmax to get probability

    # YOUR CODE GOES HERE
    states_t = torch.tensor(states, dtype=torch.float32)
    with torch.no_grad():
        logits = model(states_t)
        probs_t = torch.softmax(logits, dim=-1)
        probs = probs_t.numpy()
    assert probs is not None, "probs is not defined"

    return probs

# %%
test_states = np.array([env.reset()[0] for _ in range(5)])
test_probas = predict_probs(test_states)
assert isinstance(test_probas, np.ndarray), \
    "you must return np array and not %s" % type(test_probas)
assert tuple(test_probas.shape) == (test_states.shape[0], env.action_space.n), \
    "wrong output shape: %s" % np.shape(test_probas)
assert np.allclose(np.sum(test_probas, axis=1), 1), "probabilities do not sum to 1"

# %% [markdown]
# ### Play the game
#
# We can now use our newly built agent to play the game.

# %%
def generate_session(env, t_max=1000):
    """
    Play a full session with REINFORCE agent.
    Returns sequences of states, actions, and rewards.
    """
    # arrays to record session
    states, actions, rewards = [], [], []
    s, info = env.reset()

    for t in range(t_max):
        # action probabilities array aka pi(a|s)
        action_probs = predict_probs(np.array([s]))[0]

        # Sample action with given probabilities.
        a = np.random.choice(n_actions, p=action_probs)
        new_s, r, done, truncated, info = env.step(a)

        # record session history to train later
        states.append(s)
        actions.append(a)
        rewards.append(r)

        s = new_s
        if done:
            break

    return states, actions, rewards

# %%
# test it
states, actions, rewards = generate_session(env)

# %% [markdown]
# ### Computing cumulative rewards
#
# To work with sequential environments we need the cumulative discounted reward for known for every state. To compute it we can **roll back** from the end of the session to the beginning and compute the discounted cumulative reward as following:
#
# $$
# \begin{align*}
# G_t &= r_t + \gamma r_{t + 1} + \gamma^2 r_{t + 2} + \ldots \\
# &= \sum_{i = t}^T \gamma^{i - t} r_i \\
# &= r_t + \gamma * G_{t + 1}
# \end{align*}
# $$

# %%
def get_cumulative_rewards(rewards,  # rewards at each step
                           gamma=0.99  # discount for reward
                           ):
    """
    Take a list of immediate rewards r(s,a) for the whole session
    and compute cumulative returns (a.k.a. G(s,a) in Sutton '16).

    G_t = r_t + gamma*r_{t+1} + gamma^2*r_{t+2} + ...

    A simple way to compute cumulative rewards is to iterate from the last
    to the first timestep and compute G_t = r_t + gamma*G_{t+1} recurrently

    You must return an array/list of cumulative rewards with as many elements as in the initial rewards.
    """
    # YOUR CODE GOES HERE
    cumulative_rewards = []
    G = 0.0 
    for r in reversed(rewards):
        G = r + gamma * G 
        cumulative_rewards.insert(0, G)
    assert cumulative_rewards is not None, "cumulative_rewards is not defined"

    return cumulative_rewards

# %%
get_cumulative_rewards(rewards)
assert len(get_cumulative_rewards(list(range(100)))) == 100
assert np.allclose(
    get_cumulative_rewards([0, 0, 1, 0, 0, 1, 0], gamma=0.9),
    [1.40049, 1.5561, 1.729, 0.81, 0.9, 1.0, 0.0])
assert np.allclose(
    get_cumulative_rewards([0, 0, 1, -2, 3, -4, 0], gamma=0.5),
    [0.0625, 0.125, 0.25, -1.5, 1.0, -4.0, 0.0])
assert np.allclose(
    get_cumulative_rewards([0, 0, 1, 2, 3, 4, 0], gamma=0),
    [0, 0, 1, 2, 3, 4, 0])
print("looks good!")
# Out:
# looks good!

# %% [markdown]
# ### Loss function and updates
#
# We now need to define objective and update over policy gradient.
#
# Our objective function is
#
# $$ J \approx  { 1 \over N } \sum_{s_i,a_i} G(s_i,a_i) $$
#
# REINFORCE defines a way to compute the gradient of the expected reward with respect to policy parameters. The formula is as follows:
#
# $$ \nabla_\theta \hat J(\theta) \approx { 1 \over N } \sum_{s_i, a_i} \nabla_\theta \log \pi_\theta (a_i \mid s_i) \cdot G_t(s_i, a_i) $$
#
# We can abuse PyTorch's capabilities for automatic differentiation by defining our objective function as follows:
#
# $$ \hat J(\theta) \approx { 1 \over N } \sum_{s_i, a_i} \log \pi_\theta (a_i \mid s_i) \cdot G_t(s_i, a_i) $$
#
# When you compute the gradient of that function with respect to network weights $\theta$, it will become exactly the policy gradient.
#
# Final loss should also include the entropy regularization term $H(\pi_\theta (a_i \mid s_i))$ to enforce the exploration:
#
# $$
# L = -\hat J(\theta) - \lambda H(\pi_\theta (a_i \mid s_i)),
# $$
# where $\lambda$ is the `entropy_coef`.

# %% [markdown]
# This function might be useful:

# %%
def to_one_hot(y_tensor, ndims):
    """ helper: take an integer vector and convert it to 1-hot matrix. """
    y_tensor = y_tensor.type(torch.LongTensor).view(-1, 1)
    y_one_hot = torch.zeros(
        y_tensor.size()[0], ndims).scatter_(1, y_tensor, 1)
    return y_one_hot

# %%
def get_loss(states, actions, rewards, gamma=0.99, entropy_coef=1e-2):
    """
    Compute the loss for the REINFORCE algorithm.
    """
    states = torch.tensor(states, dtype=torch.float32)
    actions = torch.tensor(actions, dtype=torch.int32)
    cumulative_returns = np.array(get_cumulative_rewards(rewards, gamma))
    cumulative_returns = torch.tensor(cumulative_returns, dtype=torch.float32)

    # predict logits, probas and log-probas using an agent.
    logits = model(states)
    assert logits is not None, "logits is not defined"

    probs = torch.softmax(logits, dim=-1)
    assert probs is not None, "probs is not defined"

    log_probs = torch.log(probs)
    assert log_probs is not None, "log_probs is not defined"

    assert all(isinstance(v, torch.Tensor) for v in [logits, probs, log_probs]), \
        "please use compute using torch tensors and don't use predict_probs function"

    # select log-probabilities for chosen actions, log pi(a_i|s_i)
    actions_one_hot = to_one_hot(actions, ndims=log_probs.shape[1]).float()
    log_probs_for_actions = torch.sum(log_probs * actions_one_hot, dim=1)
    assert log_probs_for_actions is not None, "log_probs_for_actions is not defined"
    J_hat = torch.mean(cumulative_returns * log_probs_for_actions)
    assert J_hat is not None, "J_hat is not defined"
    
    # Compute loss here. Don't forget entropy regularization with `entropy_coef`
    entropy = -torch.mean(torch.sum(probs * log_probs, dim=1))
    assert entropy is not None, "entropy is not defined"
    loss = -J_hat - entropy_coef * entropy
    assert loss is not None, "loss is not defined"

    return loss

# %%
# Your code: define optimizers
optimizer = torch.optim.Adam(model.parameters(), 1e-3)


def train_on_session(states, actions, rewards, optimizer=optimizer, gamma=0.99, entropy_coef=1e-2):
    """
    Takes a sequence of states, actions and rewards produced by generate_session.
    Updates agent's weights by following the policy gradient above.
    Please use Adam optimizer with default parameters.
    """

    loss = get_loss(states, actions, rewards, gamma, entropy_coef)

    # Gradient descent step
    loss.backward()

    # Optimizer step
    optimizer.step()

    # Zero gradients step
    optimizer.zero_grad()

    # technical: return session rewards to print them later
    return np.sum(rewards)

# %% [markdown]
# ### The actual training

# %%
for i in range(500):
    rewards = [train_on_session(*generate_session(env), entropy_coef=1e-3) for _ in range(100)]  # generate new sessions

    print("mean reward:%.3f" % (np.mean(rewards)))

    if np.mean(rewards) > 800:
        print("You Win!")  # but you can train even further
        break
# Out:
# mean reward:21.280
# mean reward:23.870
# mean reward:20.540
# mean reward:22.280
# mean reward:20.280
# mean reward:21.520
# mean reward:22.830
# mean reward:22.240
# mean reward:20.780
# mean reward:21.570
# mean reward:22.280
# mean reward:22.340
# mean reward:22.290
# mean reward:21.610
# mean reward:22.730
# mean reward:21.560
# mean reward:22.430
# mean reward:19.300
# mean reward:23.800
# mean reward:20.720
# mean reward:23.720
# mean reward:21.420
# mean reward:21.490
# mean reward:22.420
# mean reward:21.800
# mean reward:23.200
# mean reward:25.360
# mean reward:22.660
# mean reward:21.220
# mean reward:21.270
# mean reward:23.650
# mean reward:21.140
# mean reward:21.290
# mean reward:23.110
# mean reward:21.690
# mean reward:23.170
# mean reward:21.410
# mean reward:23.010
# mean reward:21.610
# mean reward:22.810
# mean reward:24.310
# mean reward:21.990
# mean reward:23.330
# mean reward:23.200
# mean reward:24.370
# mean reward:24.630
# mean reward:24.560
# mean reward:25.330
# mean reward:25.150
# mean reward:25.340
# mean reward:23.970
# mean reward:25.950
# mean reward:25.740
# mean reward:22.360
# mean reward:27.680
# mean reward:27.660
# mean reward:26.340
# mean reward:27.580
# mean reward:29.880
# mean reward:26.420
# mean reward:29.300
# mean reward:33.400
# mean reward:30.460
# mean reward:30.200
# mean reward:29.240
# mean reward:32.670
# mean reward:32.070
# mean reward:30.960
# mean reward:28.020
# mean reward:35.520
# mean reward:35.920
# mean reward:36.130
# mean reward:42.560
# mean reward:47.290
# mean reward:48.330
# mean reward:54.500
# mean reward:60.150
# mean reward:68.830
# mean reward:97.890
# mean reward:121.050
# mean reward:164.020
# mean reward:202.630
# mean reward:199.190
# mean reward:221.670
# mean reward:221.180
# mean reward:183.950
# mean reward:204.020
# mean reward:199.450
# mean reward:125.870
# mean reward:182.330
# mean reward:146.300
# mean reward:326.220
# mean reward:155.930
# mean reward:295.690
# mean reward:407.240
# mean reward:512.810
# mean reward:340.730
# mean reward:215.520
# mean reward:160.190
# mean reward:135.560
# mean reward:182.480
# mean reward:230.780
# mean reward:225.480
# mean reward:220.470
# mean reward:261.400
# mean reward:195.210
# mean reward:198.950
# mean reward:152.210
# mean reward:160.310
# mean reward:375.910
# mean reward:248.970
# mean reward:159.180
# mean reward:148.280
# mean reward:250.390
# mean reward:164.580
# mean reward:130.660
# mean reward:126.180
# mean reward:163.450
# mean reward:146.800
# mean reward:154.310
# mean reward:156.640
# mean reward:114.060
# mean reward:134.880
# mean reward:108.400
# mean reward:105.760
# mean reward:130.450
# mean reward:209.560
# mean reward:246.970
# mean reward:125.140
# mean reward:156.570
# mean reward:134.990
# mean reward:109.040
# mean reward:117.160
# mean reward:130.790
# mean reward:118.260
# mean reward:102.470
# mean reward:94.460
# mean reward:82.910
# mean reward:88.180
# mean reward:100.270
# mean reward:102.580
# mean reward:121.870
# mean reward:135.460
# mean reward:122.770
# mean reward:113.500
# mean reward:134.350
# mean reward:407.040
# mean reward:979.920
# You Win!

# %% [markdown]
# ### Watch the video of your results:

# %%
# !pip install "gymnasium[other]"
# Out:
# Requirement already satisfied: gymnasium[other] in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from gymnasium[other]) (2.1.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from gymnasium[other]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from gymnasium[other]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from gymnasium[other]) (0.0.4)
# Collecting moviepy>=1.0.0 (from gymnasium[other])
#   Downloading moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib>=3.0 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from gymnasium[other]) (3.10.5)
# Collecting opencv-python>=3.0 (from gymnasium[other])
#   Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: seaborn>=0.13 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from gymnasium[other]) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from matplotlib>=3.0->gymnasium[other]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from moviepy>=1.0.0->gymnasium[other]) (5.2.1)
# Collecting imageio<3.0,>=2.5 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[other])
#   Downloading proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy>=1.0.0->gymnasium[other])
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tqdm in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[other]) (4.67.1)
# Requirement already satisfied: six>=1.5 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[other]) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from seaborn>=0.13->gymnasium[other]) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/baga/github/ml-course/venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Downloading moviepy-2.2.1-py3-none-any.whl (129 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 4.4 MB/s  0:00:04m 4.2 MB/s eta 0:00:01
# Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 5.5 MB/s  0:00:06a 0:00:010:00:01:01
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, proglog, opencv-python, imageio_ffmpeg, imageio, moviepy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [moviepy]━━━━━━━━━━ 4/6 [imageio]
# Successfully installed imageio-2.37.0 imageio_ffmpeg-0.6.0 moviepy-2.2.1 opencv-python-4.12.0.88 proglog-0.1.12 python-dotenv-1.1.1

# %%
import os
import numpy as np
import gymnasium as gym
from gymnasium.utils.save_video import save_video

env_for_video = gym.make("CartPole-v1", render_mode="rgb_array_list")
n_actions = env_for_video.action_space.n

episode_index = 0
step_starting_index = 0

obs, info = env_for_video.reset()

for step_index in range(800):
    probs = predict_probs(np.array([obs]))[0]
    action = np.random.choice(n_actions, p=probs)

    obs, reward, terminated, truncated, info = env_for_video.step(action)
    done = terminated or truncated

    if done or step_index == 799:
        # env_for_video.render() now returns the LIST of frames accumulated so far
        frames = env_for_video.render()
        os.makedirs("videos", exist_ok=True)
        save_video(
            frames, "videos",
            fps=env_for_video.metadata.get("render_fps", 30),
            step_starting_index=step_starting_index,
            episode_index=episode_index,
        )
        episode_index += 1
        step_starting_index = step_index + 1
        obs, info = env_for_video.reset()

env_for_video.close()

# %% [markdown]
# Congratulations! Finally, copy the `predict_probs`, `get_cumulative_rewards` and `get_loss` to the template and submit them to the Contest.
#
# Good luck!

# %% [markdown]
# ## Bonus part (no points, just for the interested ones)
#
# Try solving the `Acrobot-v1` environment. It is more complex than regular `CartPole-v1`, so the default Policy Gradient (REINFORCE) algorithm might not work. Maybe the baseline idea could help...
#
# ![Acrobot](https://gymnasium.farama.org/_images/acrobot.gif)

# %%
env = gym.make("Acrobot-v1", render_mode="rgb_array")


env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape

plt.imshow(env.render())

# %%
# Your brave and victorious code here.
